# %% [markdown]
# # HW8
# ## 2021158041 한수빈

# %% [markdown]
# ## movies 실습

# %%
import pandas as pd
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_csv('movies.csv',header=None,names = mnames)[1:10]
movies.set_index("movie_id")
# Out:
#                                        title  \
# movie_id
# 1                           Toy Story (1995)
# 2                             Jumanji (1995)
# 3                    Grumpier Old Men (1995)
# 4                   Waiting to Exhale (1995)
# 5         Father of the Bride Part II (1995)
# 6                                Heat (1995)
# 7                             Sabrina (1995)
# 8                        Tom and Huck (1995)
# 9                        Sudden Death (1995)
#
#                                                genres
# movie_id
# 1         Adventure|Animation|Children|Comedy|Fantasy
# 2                          Adventure|Children|Fantasy
# 3                                      Comedy|Romance
# 4                                Comedy|Drama|Romance
# 5                                              Comedy
# 6                               Action|Crime|Thriller
# 7                                      Comedy|Romance
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.1

# %%
for node in G : 
    print(node)
# Out:
# 1
# P
# Hi
# 2
# 3

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.2

# %%
G.add_nodes_from([3,4])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]

# %% [markdown]
# 나) 3의 노드가 이미 존재하므로 4의 노드만 추가될 것이다.

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.3

# %%
G.add_edge(4,5)
print(G.edges())
# Out:
# [(4, 5)]

# %% [markdown]
# 다) 5의 노드가 존재하지 않아 5의 노드를 생성한 후 4와 연결할 것이다.

# %%
G.add_edges_from([(1,2),(1,3),(1,4),(1,5)])
print(G.edges())
# Out:
# [(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)]

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.4

# %%
G.add_edges_from([(1, 'P'), (1, 'Hi')])
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.5

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])

# %%
G.remove_edge(1,3)

# %%
print('No. nodes : ', G.number_of_nodes())
print('No. edges : ', G.number_of_edges())
# Out:
# No. nodes :  5
# No. edges :  4

# %%
nx.draw(G, with_labels=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.6

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])

# %%
G.remove_node(4)

# %%
print('No. nodes : ', G.number_of_nodes())
print('No. edges : ', G.number_of_edges())
# Out:
# No. nodes :  4
# No. edges :  3

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.7

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])

# %%
G.remove_nodes_from([4,5])

# %%
print('No. nodes : ', G.number_of_nodes())
print('No. edges : ', G.number_of_edges())
# Out:
# No. nodes :  3
# No. edges :  2

# %%
nx.draw(G, with_labels=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.8

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import bernoulli
def erdosGraph(N, p) :
    G = nx.Graph()
    G.add_nodes_from(range(N))
    listG = list(G.nodes())
    for node1 in range(N) :
        for node2 in range(N) :
            if(bernoulli.rvs(p=p)) :
                G.add_edge(node1, node2)
    return G

# %%
nx.draw(erdosGraph(20, 0.18))

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.9

# %% [markdown]
# `utf-8`로 `csv` 파일을 생성하면 파일 맨 앞에 `\ufeff` 가 추가된다.
# 이를 제거하려면 `encoding='utf-8-sig'`를 추가한다.

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("test1.csv", delimiter=",",encoding='utf-8-sig') 
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.10

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("test2.csv", delimiter=",", encoding='utf-8-sig')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.11

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G = nx.karate_club_graph()

# %%
plt.xlabel('Degree')
plt.ylabel('Prob. of node degree')
plt.hist(list([d for n, d in G.degree()]), histtype='step')
# Out:
# (array([12., 12.,  3.,  2.,  0.,  2.,  1.,  0.,  0.,  2.]),
#  array([ 1. ,  2.6,  4.2,  5.8,  7.4,  9. , 10.6, 12.2, 13.8, 15.4, 17. ]),
#  [<matplotlib.patches.Polygon at 0x7fe80b10da00>])

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.12

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G = nx.karate_club_graph()

# %%
pos, degree = max([(n, d) for n, d in G.degree()])
print('노드 : ', pos, ' 차수 : ', degree)
print(G.degree())
nx.draw(G, with_labels=True, node_size=100, node_color='yellow', edge_color='red')
# Out:
# 노드 :  33  차수 :  17
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.13

# %%
print(G.degree())
# Out:
# [('BrighamYoung', 12), ('FloridaState', 12), ('Iowa', 12), ('KansasState', 12), ('NewMexico', 11), ('TexasTech', 12), ('PennState', 12), ('SouthernCalifornia', 12), ('ArizonaState', 11), ('SanDiegoState', 11), ('Baylor', 10), ('NorthTexas', 10), ('NorthernIllinois', 10), ('Northwestern', 11), ('WesternMichigan', 10), ('Wisconsin', 12), ('Wyoming', 11), ('Auburn', 11), ('Akron', 11), ('VirginiaTech', 11), ('Alabama', 11), ('UCLA', 11), ('Arizona', 11), ('Utah', 11), ('ArkansasState', 10), ('NorthCarolinaState', 11), ('BallState', 10), ('Florida', 11), ('BoiseState', 9), ('BostonCollege', 11), ('WestVirginia', 11), ('BowlingGreenState', 11), ('Michigan', 11), ('Virginia', 10), ('Buffalo', 11), ('Syracuse', 11), ('CentralFlorida', 8), ('GeorgiaTech', 11), ('CentralMichigan', 11), ('Purdue', 11), ('Colorado', 11), ('ColoradoState', 10), ('Connecticut', 7), ('EasternMichigan', 11), ('EastCarolina', 11), ('Duke', 11), ('FresnoState', 11), ('OhioState', 11), ('Houston', 11), ('Rice', 11), (
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.14

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import zipfile
zf = zipfile.ZipFile('football.zip')
txt = zf.read('football.txt').decode()
gml = zf.read('football.gml').decode()
gml = gml.split('\n')[1:]
G = nx.parse_gml(gml)

# %%
print('No. of nodes : %d' % G.number_of_nodes())
print('No. of edges : %d' % G.number_of_edges())
print('Avg. of degrees : %.1f' % np.mean([d for n, d in G.degree()]))
# Out:
# No. of nodes : 115
# No. of edges : 613
# Avg. of degrees : 10.7

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.15

# %%
nx.draw(klist[1], with_labels=True, node_color='yellow', edge_color='red')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.16

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("social.csv", delimiter=",")
G = nx.to_networkx_graph(K)

ksub = (G.subgraph(c) for c in nx.connected_components(G))


maxG = min([G.subgraph(c) for c in nx.connected_components(G)], key=len)
nx.draw(maxG, with_labels=True, node_color='yellow', edge_color='red')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.17

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("social2.csv", delimiter=",")

# %%
G = nx.to_networkx_graph(K)
ksub = (G.subgraph(c) for c in nx.connected_components(G))
ksub = list(ksub)
klist = list(ksub)
print(len(klist))
# Out:
# 3

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.18

# %%
print(klist[2].degree())
nx.draw(klist[2], with_labels=True, node_color='yellow')
# Out:
# [(17, 3), (18, 3), (19, 3), (20, 3)]

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.19

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("social.csv", delimiter=",")
G = nx.to_networkx_graph(K)

# %%
maxG = max([G.subgraph(c) for c in nx.connected_components(G)], key=len)
nx.draw(maxG, with_labels=True, node_color='yellow', edge_color='red')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.20

# %%
ix = birdata.bird_name == "Sanne"
date = birdata.date_time[ix]
print(date[0:1])
# Out:
# 40923    2013-08-15 00:01:08+00
# Name: date_time, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.21

# %%
date = birdata.date_time[ix]
print(date[-1:])
# Out:
# 61930    2014-04-30 23:59:34+00
# Name: date_time, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.22

# %%
elapsed[100] / dt.timedelta(hours=1)
# Out:
# 29.41138888888889

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.23

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.plot(range(50), speed[:50]);
plt.xlabel('Observation')
plt.ylabel('Flying Speed');

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.24

# %%
import matplotlib.pyplot as plt
speed = birdata.speed_2d[birdata.bird_name == 'Eric']

# %%
plt.plot(range(50), speed[:50]);
plt.xlabel('Observation')
plt.ylabel('Flying Speed')
# Out:
# Text(0, 0.5, 'Flying Speed')

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.25

# %%
import pandas as pd
birdata = pd.read_csv('bird_tracking.csv')
speed = birdata.speed_2d[birdata.bird_name == 'Eric']
import numpy as np
speed = np.array(speed)
np.isnan(speed)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
nanlist = []
def getnan(s) :
    for i, n in enumerate(s) :
        if np.isnan(n):
            nanlist.append(i)
getnan(speed)
print('nan의 총개수 : ', len(nanlist))
print(nanlist)
# Out:
# nan의 총개수 :  85
# [219, 1006, 1232, 1255, 1531, 1731, 2470, 3219, 3406, 3413, 3430, 3436, 3597, 3617, 3638, 3738, 3743, 4049, 4068, 4120, 4149, 4357, 4514, 4594, 4689, 4779, 4929, 4984, 5010, 5027, 5117, 5158, 5736, 5745, 5904, 6003, 6572, 6665, 6934, 6974, 7430, 7597, 8180, 8933, 9202, 9325, 9357, 9426, 9593, 10107, 10143, 10153, 10163, 10553, 10942, 10944, 11321, 12618, 12762, 13096, 13182, 13284, 14110, 14476, 14997, 15031, 15104, 15579, 15774, 15811, 15910, 16785, 16977, 17947, 18235, 18316, 19196, 19519, 19528, 19548, 19623, 19624, 19756, 19774, 19781]

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.26

# %%
pd.Series(bird_dict)
# Out:
# Eric     22.599113
# Nico     43.449202
# Sanne    40.871441
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Quiz 13.27

# %%
bird_names = pd.unique(birdata.bird_name)
bird_dict = {}
def euc(a,b) :
    return distance.euclidean(a,b)
start = 0
end = 0
count = 0
for bird_name in bird_names :
    ix = birdata['bird_name'] == bird_name
    x, y = birdata.longitude[ix], birdata.latitude[ix]
    longest = 0
    i = [x[start], y[start]]
    for ind in range(len(x) -1) :
        j = [x[start+ind+1], y[start+ind+1]]
        newlength = euc(i,j)
        distlist.append(newlength)
        if(euc(i,j) > longest) :
            longest = newlength
    bird_dict[bird_names[count]] = (longest / 360) * 40000
    count = count + 1
    start = start + len(x)
    dest = dest + len(x)
print(bird_dict)
# Out:
# {'Eric': 2511.012525041367, 'Nico': 4827.689090091932, 'Sanne': 4541.271186064482}

# %% [markdown]
# ---
