# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)

for row in data :
    print(row)
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차', '작업일시']
# ['2020-09', '1호선', '1', '서울역', '724,320', '711,203', '137,054', '128,369', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '10', '동묘앞', '106,120', '112,366', '123,144', '123,667', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '2', '시청', '376,545', '376,445', '50,389', '47,503', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '3', '종각', '600,944', '591,275', '95,352', '89,734', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '4', '종로3가', '316,661', '287,846', '226,692', '213,457', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '5', '종로5가', '295,041', '301,544', '198,655', '190,007', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '6', '동대문', '184,244', '184,462', '94,355', '95,369', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '7', '신설동', '226,849', '227,364', '92,148', '88,012', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '8', '제기동', '202,713', '199,630', '246,990', '268,967', '2020-10-03 09:02:28']
# ...

# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)
next(data)

for row in data :
    row[4] = int(row[4].replace(',',''))
    print(row)
# Out:
# ['2020-09', '1호선', '1', '서울역', 724320, '711,203', '137,054', '128,369', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '10', '동묘앞', 106120, '112,366', '123,144', '123,667', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '2', '시청', 376545, '376,445', '50,389', '47,503', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '3', '종각', 600944, '591,275', '95,352', '89,734', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '4', '종로3가', 316661, '287,846', '226,692', '213,457', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '5', '종로5가', 295041, '301,544', '198,655', '190,007', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '6', '동대문', 184244, '184,462', '94,355', '95,369', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '7', '신설동', 226849, '227,364', '92,148', '88,012', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '8', '제기동', 202713, '199,630', '246,990', '268,967', '2020-10-03 09:02:28']
# ['2020-09', '1호선', '9', '청량리(서울시립대입구)', 278851, '272,423', '242,323', '252,268', '2020-10-03 09:02:28']
# ...

# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)
next(data)

for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    print(row)
# Out:
# ['2020-09', '1호선', '1', '서울역', 724320, 711203, 137054, 128369, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '10', '동묘앞', 106120, 112366, 123144, 123667, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '2', '시청', 376545, 376445, 50389, 47503, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '3', '종각', 600944, 591275, 95352, 89734, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '4', '종로3가', 316661, 287846, 226692, 213457, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '5', '종로5가', 295041, 301544, 198655, 190007, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '6', '동대문', 184244, 184462, 94355, 95369, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '7', '신설동', 226849, 227364, 92148, 88012, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '8', '제기동', 202713, 199630, 246990, 268967, '2020-10-03 09:02:28']
# ['2020-09', '1호선', '9', '청량리(서울시립대입구)', 278851, 272423, 242323, 252268, '2020-10-03 09:02:28']
# ['2020-09', '2호선', '11', '시청', 431147, 424000, 35332, 31482, '2020-10-03 09:02:28']
# ...

# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    rate = row[4] / row[6] # ZeroDivisionError 발생 
    if rate > mx :
        mx = rate
print(mx)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [16], in <cell line: 7>()
#       8 for i in range(4,8) :
#       9     row[i] = int(row[i].replace(',',''))
# ---> 10 rate = row[4] / row[6] # ZeroDivisionError 발생
#      11 if rate > mx :
#      12     mx = rate
#
# ZeroDivisionError: division by zero

# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    if row[6] == 0 : # row[6]이 0인 경우 출력 
        print(row)
# Out:
# ['2020-09', '경원선', '142', '창동', 6, 0, 0, 0, '2020-10-03 09:02:28']
# ['2020-09', '분당선', '150', '복정', 7, 0, 0, 0, '2020-10-03 09:02:28']
# ['2020-09', '일산선', '375', '지축', 1, 0, 0, 0, '2020-10-03 09:02:28']
# ['2020-09', '경의선', '203', '계양', 4, 0, 0, 0, '2020-10-03 09:02:28']
# ['2020-09', '6호선', '476', '신내', 5, 0, 0, 0, '2020-10-03 09:02:28']

# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    if row[6] != 0 :
        rate = row[4] / row[6]
        if rate > mx :
            mx = rate
            print(row, round(rate,2))
# Out:
# ['2020-09', '1호선', '1', '서울역', 724320, 711203, 137054, 128369, '2020-10-03 09:02:28'] 5.28
# ['2020-09', '1호선', '2', '시청', 376545, 376445, 50389, 47503, '2020-10-03 09:02:28'] 7.47
# ['2020-09', '2호선', '11', '시청', 431147, 424000, 35332, 31482, '2020-10-03 09:02:28'] 12.2
# ['2020-09', '2호선', '19', '한양대', 144842, 154060, 10034, 10448, '2020-10-03 09:02:28'] 14.44
# ['2020-09', '2호선', '49', '홍대입구', 1002313, 1070633, 68516, 65912, '2020-10-03 09:02:28'] 14.63
# ['2020-09', '경부선', '121', '서울역', 90923, 26723, 5768, 1418, '2020-10-03 09:02:28'] 15.76
# ['2020-09', '6호선', '442', '연신내', 16, 0, 1, 0, '2020-10-03 09:02:28'] 16.0
# ['2020-09', '공항철도 1호선', '642', '디지털미디어시티', 251648, 228016, 15680, 14558, '2020-10-03 09:02:28'] 16.05
# ['2020-09', '공항철도 1호선', '643', '마곡나루(서울식물원)', 143576, 135549, 7975, 7866, '2020-10-03 09:02:28'] 18.0

# %%
import csv
f = open('subwayfee2020-09.csv', encoding="MS949")
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i])
    if row[6] !=0 and (row[4] + row[6]) >100000 :
        rate = row[4] / (row[4] + row[6])
        if rate > mx :
            mx = rate
            print(row, round(rate,2))

# %%
import csv
f = open('subwayfee2020-09.csv')
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    if row[6] !=0 and (row[4] + row[6]) >100000 :
        rate = row[4] / (row[4] + row[6])
        if rate > 0.94 :
            mx = rate
            print(row, round(rate,2))

# %%
import csv
f = open('subwayfee2020-09.csv')
data = csv.reader(f)
next(data)
mx = 0
rate = 0
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    if row[6] !=0 and (row[4] + row[6]) >100000 :
        rate = row[4] / (row[4] + row[6])
        if rate > mx :
            mx = rate
            mx_station = row[3] + ' ' + row[1]

print(mx_station, round(mx * 100,2))

# %%
import csv
f = open('subwayfee2020-09.csv')
data = csv.reader(f)
next(data)
mx = [0] * 4
mx_station = [''] * 4

for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
        if row[i] > mx[i-4] :
            mx[i-4] = row[i]
            mx_station[i-4] = row[3] + ' ' + row[1]
            
for i in range(4) :
    print(mx_station[i], mx[i])

# %%
import csv
f = open('subwayfee.csv')
data = csv.reader(f)
next(data)
mx = [0] * 4
mx_station = [''] * 4
label = ['유임승차','유임하차','무임승차','무임하차']
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
        if row[i] > mx[i-4] :
            mx[i-4] = row[i]
            mx_station[i-4] = row[3] + ' ' + row[1]
for i in range(4) :
    print(label[i] + ' : ' + mx_station[i], mx[i])

# %%
import csv
import matplotlib.pyplot as plt
f = open('subwayfee.csv')
data = csv.reader(f)
next(data)
label = ['유임승차','유임하차','무임승차','무임하차']
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i])
    #plt.figure(dpi = 300)
    plt.pie(row[4:8])
    plt.axis('equal')
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('subwayfee.csv')
data = csv.reader(f)
next(data)
label = ['유임승차','유임하차','무임승차','무임하차']
c = ['#14CCC0', '#389993', '#FF1C6A', '#CC14AF']
plt.rc('font', family = 'Malgun Gothic')
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i])
    plt.figure(dpi = 300)
    plt.title(row[3] + ' ' + row[1])
    plt.pie(row[4:8], labels = label, colors = c, autopct = '%1.f%%')
    plt.axis('equal')
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('subwayfee2020-09.csv')
data = csv.reader(f)
next(data)
label = ['유임승차','유임하차','무임승차','무임하차']
c = ['#14CCC0', '#389993', '#FF1C6A', '#CC14AF']
plt.rc('font', family = 'Malgun Gothic')
for row in data :
    for i in range(4,8) :
        row[i] = int(row[i].replace(',',''))
    plt.figure(dpi = 300)
    plt.title(row[3] + ' ' + row[1])
    plt.pie(row[4:8], labels = label, colors = c, autopct = '%1.f%%')
    plt.axis('equal')
    plt.savefig(row[3] + ' ' + row[1] + '.png')
    plt.show()
